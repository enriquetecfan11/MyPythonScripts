# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from requests.exceptions import ChunkedEncodingError
import re
import os
from deep_translator import GoogleTranslator
import glob
import nltk
from nltk import FreqDist, word_tokenize
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
nltk.download('stopwords')

# %%
# Cargar el archivo CSV en un DataFrame
df = pd.read_csv('ideas_limpias.csv')

# Crear la carpeta si no existe
carpeta_export = 'csv-export'
os.makedirs(carpeta_export, exist_ok=True)

# Dividir el DataFrame por etiquetas y guardar cada subconjunto en un archivo en la carpeta
for etiqueta, subconjunto in df.groupby('Tag'):
    # Crear el nombre del archivo y la ruta en la carpeta
    nombre_archivo = f'{etiqueta}_subconjunto.csv'
    ruta_archivo = os.path.join(carpeta_export, nombre_archivo)
    
    # Guardar el subconjunto en el archivo en la carpeta
    subconjunto.to_csv(ruta_archivo, index=False)

    print(f'Se ha creado el archivo {ruta_archivo} con {len(subconjunto)} filas.')

# %%
# Carpeta que contiene los archivos CSV exportados
carpeta_export = 'csv-export'

# Obtener la lista de archivos CSV en la carpeta csv-export
archivos_csv = [f for f in os.listdir(carpeta_export) if f.endswith('.csv')]

# Función para obtener las palabras clave de un texto
def obtener_palabras_clave(texto, cantidad_palabras=5):
    tokens = word_tokenize(texto)
    tokens = [token.lower() for token in tokens if token.isalnum() and token.lower() not in stopwords.words('english')]
    frecuencia = FreqDist(tokens)
    return [palabra for palabra, _ in frecuencia.most_common(cantidad_palabras)]

# Iterar sobre los archivos CSV
for archivo_csv in archivos_csv:
    
    # Leer el archivo CSV en un DataFrame
    df = pd.read_csv(os.path.join(carpeta_export, archivo_csv))

    # Agregar una columna para las palabras clave
    df['Palabras clave'] = df['Idea'].apply(lambda x: obtener_palabras_clave(x))

    # Guardar el DataFrame actualizado en el mismo archivo CSV
    df.to_csv(os.path.join(carpeta_export, archivo_csv), index=False)

    # Imprimir el DataFrame con las palabras clave
    print(f'DataFrame con palabras clave para {archivo_csv}\n')
    
    # Imprimir el numero de archvivos recorridos y lo que faltan
    print(f'Archivo {archivo_csv} de {len(archivos_csv)}')
    print(f'Faltan {len(archivos_csv) - archivos_csv.index(archivo_csv) - 1} archivos\n')
# Out:
# DataFrame con palabras clave para 3d Startup Ideas_subconjunto.csv
#
# Archivo 3d Startup Ideas_subconjunto.csv de 1637
# Faltan 1636 archivos
#
# DataFrame con palabras clave para Ability Startup Ideas_subconjunto.csv
#
# Archivo Ability Startup Ideas_subconjunto.csv de 1637
# Faltan 1635 archivos
#
# DataFrame con palabras clave para Able Startup Ideas_subconjunto.csv
#
# Archivo Able Startup Ideas_subconjunto.csv de 1637
# Faltan 1634 archivos
#
# DataFrame con palabras clave para Abroad Startup Ideas_subconjunto.csv
#
# Archivo Abroad Startup Ideas_subconjunto.csv de 1637
# Faltan 1633 archivos
#
# DataFrame con palabras clave para Accelerator Startup Ideas_subconjunto.csv
#
# Archivo Accelerator Startup Ideas_subconjunto.csv de 1637
# Faltan 1632 archivos
#
# DataFrame con palabras clave para Accept Startup Ideas_subconjunto.csv
#
# Archivo Accept Startup Ideas_subconjunto.csv de 1637
# Faltan 1631 archivos
#
# DataFrame con palabras clave para Accepted Startup Ideas_subconjunto.csv
#
# Archivo Accepted Startup Ideas_subconjunto.csv de 1637
# Faltan 1630 archivos
#
# DataFrame con palabras clave para Accessed Startup Ideas_subconjunto.csv
#
# Archivo Accessed Startup Ideas_subconjunto.csv de 1637
# Faltan 1629 archivos
#
# DataFrame con palabras clave para Accessible Startup Ideas_subconjunto.csv
#
# Archivo Accessible Startup Ideas_subconjunto.csv de 1637
# Faltan 1628 archivos
#
# DataFrame con palabras clave para According Startup Ideas_subconjunto.csv
#
# Archivo According Startup Ideas_subconjunto.csv de 1637
# Faltan 1627 archivos
#
# DataFrame con palabras clave para Account Startup Ideas_subconjunto.csv
#
# Archivo Account Startup Ideas_subconjunto.csv de 1637
# Faltan 1626 archivos
#
# DataFrame con palabras clave para Accounting Startup Ideas_subconjunto.csv
#
# Archivo Accounting Startup Ideas_subconjunto.csv de 1637
# Faltan 1625 archivos
#
# DataFrame con palabras clave para Accurate Startup Ideas_subconjunto.csv
#
# Archivo Accurate Startup Ideas_subconjunto.csv de 1637
# Faltan 1624 archivos
#
# DataFrame con palabras clave para Accurately Startup Ideas_subconjunto.csv
#
# Archivo Accurately Startup Ideas_subconjunto.csv de 1637
# Faltan 1623 archivos
#
# DataFrame con palabras clave para Achieve Startup Ideas_subconjunto.csv
#
# Archivo Achieve Startup Ideas_subconjunto.csv de 1637
# Faltan 1622 archivos
#
# DataFrame con palabras clave para Acquired Startup Ideas_subconjunto.csv
#
# Archivo Acquired Startup Ideas_subconjunto.csv de 1637
# Faltan 1621 archivos
#
# DataFrame con palabras clave para Acquisition Startup Ideas_subconjunto.csv
#
# Archivo Acquisition Startup Ideas_subconjunto.csv de 1637
# Faltan 1620 archivos
#
# DataFrame con palabras clave para Act Startup Ideas_subconjunto.csv
#
# Archivo Act Startup Ideas_subconjunto.csv de 1637
# Faltan 1619 archivos
#
# DataFrame con palabras clave para Action Startup Ideas_subconjunto.csv
#
# Archivo Action Startup Ideas_subconjunto.csv de 1637
# Faltan 1618 archivos
#
# DataFrame con palabras clave para Actionable Startup Ideas_subconjunto.csv
#
# Archivo Actionable Startup Ideas_subconjunto.csv de 1637
# Faltan 1617 archivos
#
# DataFrame con palabras clave para Activated Startup Ideas_subconjunto.csv
#
# Archivo Activated Startup Ideas_subconjunto.csv de 1637
# Faltan 1616 archivos
#
# DataFrame con palabras clave para Active Startup Ideas_subconjunto.csv
#
# Archivo Active Startup Ideas_subconjunto.csv de 1637
# Faltan 1615 archivos
#
# DataFrame con palabras clave para Activity Startup Ideas_subconjunto.csv
#
# Archivo Activity Startup Ideas_subconjunto.csv de 1637
# Faltan 1614 archivos
#
# DataFrame con palabras clave para Actual Startup Ideas_subconjunto.csv
#
# Archivo Actual Startup Ideas_subconjunto.csv de 1637
# Faltan 1613 archivos
#
# DataFrame con palabras clave para Actually Startup Ideas_subconjunto.csv
#
# Archivo Actually Startup Ideas_subconjunto.csv de 1637
# Faltan 1612 archivos
#
# DataFrame con palabras clave para Ad Startup Ideas_subconjunto.csv
#
# Archivo Ad Startup Ideas_subconjunto.csv de 1637
# Faltan 1611 archivos
#
# DataFrame con palabras clave para Add Startup Ideas_subconjunto.csv
#
# Archivo Add Startup Ideas_subconjunto.csv de 1637
# Faltan 1610 archivos
#
# DataFrame con palabras clave para Added Startup Ideas_subconjunto.csv
#
# Archivo Added Startup Ideas_subconjunto.csv de 1637
# Faltan 1609 archivos
#
# DataFrame con palabras clave para Adding Startup Ideas_subconjunto.csv
#
# Archivo Adding Startup Ideas_subconjunto.csv de 1637
# Faltan 1608 archivos
#
# DataFrame con palabras clave para Addition Startup Ideas_subconjunto.csv
#
# Archivo Addition Startup Ideas_subconjunto.csv de 1637
# Faltan 1607 archivos
#
# DataFrame con palabras clave para Adjust Startup Ideas_subconjunto.csv
#
# Archivo Adjust Startup Ideas_subconjunto.csv de 1637
# Faltan 1606 archivos
#
# DataFrame con palabras clave para Administrative Startup Ideas_subconjunto.csv
#
# Archivo Administrative Startup Ideas_subconjunto.csv de 1637
# Faltan 1605 archivos
#
# DataFrame con palabras clave para Adopt Startup Ideas_subconjunto.csv
#
# Archivo Adopt Startup Ideas_subconjunto.csv de 1637
# Faltan 1604 archivos
#
# DataFrame con palabras clave para Advance Startup Ideas_subconjunto.csv
#
# Archivo Advance Startup Ideas_subconjunto.csv de 1637
# Faltan 1603 archivos
#
# DataFrame con palabras clave para Advantage Startup Ideas_subconjunto.csv
#
# Archivo Advantage Startup Ideas_subconjunto.csv de 1637
# Faltan 1602 archivos
#
# DataFrame con palabras clave para Advertise Startup Ideas_subconjunto.csv
#
# Archivo Advertise Startup Ideas_subconjunto.csv de 1637
# Faltan 1601 archivos
#
# DataFrame con palabras clave para Advertising Startup Ideas_subconjunto.csv
#
# Archivo Advertising Startup Ideas_subconjunto.csv de 1637
# Faltan 1600 archivos
#
# DataFrame con palabras clave para Advice Startup Ideas_subconjunto.csv
#
# Archivo Advice Startup Ideas_subconjunto.csv de 1637
# Faltan 1599 archivos
#
# DataFrame con palabras clave para Advisor Startup Ideas_subconjunto.csv
#
# Archivo Advisor Startup Ideas_subconjunto.csv de 1637
# Faltan 1598 archivos
#
# DataFrame con palabras clave para Afford Startup Ideas_subconjunto.csv
#
# Archivo Afford Startup Ideas_subconjunto.csv de 1637
# Faltan 1597 archivos
#
# DataFrame con palabras clave para Affordable Startup Ideas_subconjunto.csv
#
# Archivo Affordable Startup Ideas_subconjunto.csv de 1637
# Faltan 1596 archivos
#
# DataFrame con palabras clave para Africa Startup Ideas_subconjunto.csv
#
# Archivo Africa Startup Ideas_subconjunto.csv de 1637
# Faltan 1595 archivos
#
# DataFrame con palabras clave para Against Startup Ideas_subconjunto.csv
#
# Archivo Against Startup Ideas_subconjunto.csv de 1637
# Faltan 1594 archivos
#
# DataFrame con palabras clave para Age Startup Ideas_subconjunto.csv
#
# Archivo Age Startup Ideas_subconjunto.csv de 1637
# Faltan 1593 archivos
#
# DataFrame con palabras clave para Agency Startup Ideas_subconjunto.csv
#
# Archivo Agency Startup Ideas_subconjunto.csv de 1637
# Faltan 1592 archivos
#
# DataFrame con palabras clave para Agent Startup Ideas_subconjunto.csv
#
# Archivo Agent Startup Ideas_subconjunto.csv de 1637
# Faltan 1591 archivos
#
# DataFrame con palabras clave para Aggregate Startup Ideas_subconjunto.csv
#
# Archivo Aggregate Startup Ideas_subconjunto.csv de 1637
# Faltan 1590 archivos
#
# DataFrame con palabras clave para Ahead Startup Ideas_subconjunto.csv
#
# Archivo Ahead Startup Ideas_subconjunto.csv de 1637
# Faltan 1589 archivos
#
# DataFrame con palabras clave para Ai Startup Ideas_subconjunto.csv
#
# Archivo Ai Startup Ideas_subconjunto.csv de 1637
# Faltan 1588 archivos
#
# DataFrame con palabras clave para Aid Startup Ideas_subconjunto.csv
#
# Archivo Aid Startup Ideas_subconjunto.csv de 1637
# Faltan 1587 archivos
#
# DataFrame con palabras clave para Aim Startup Ideas_subconjunto.csv
#
# Archivo Aim Startup Ideas_subconjunto.csv de 1637
# Faltan 1586 archivos
#
# DataFrame con palabras clave para Aimed Startup Ideas_subconjunto.csv
#
# Archivo Aimed Startup Ideas_subconjunto.csv de 1637
# Faltan 1585 archivos
#
# DataFrame con palabras clave para Aiming Startup Ideas_subconjunto.csv
#
# Archivo Aiming Startup Ideas_subconjunto.csv de 1637
# Faltan 1584 archivos
#
# DataFrame con palabras clave para Air Startup Ideas_subconjunto.csv
#
# Archivo Air Startup Ideas_subconjunto.csv de 1637
# Faltan 1583 archivos
#
# DataFrame con palabras clave para Airbnb Startup Ideas_subconjunto.csv
#
# Archivo Airbnb Startup Ideas_subconjunto.csv de 1637
# Faltan 1582 archivos
#
# DataFrame con palabras clave para Airline Startup Ideas_subconjunto.csv
#
# Archivo Airline Startup Ideas_subconjunto.csv de 1637
# Faltan 1581 archivos
#
# DataFrame con palabras clave para Airport Startup Ideas_subconjunto.csv
#
# Archivo Airport Startup Ideas_subconjunto.csv de 1637
# Faltan 1580 archivos
#
# DataFrame con palabras clave para Alert Startup Ideas_subconjunto.csv
#
# Archivo Alert Startup Ideas_subconjunto.csv de 1637
# Faltan 1579 archivos
#
# DataFrame con palabras clave para Alexa Startup Ideas_subconjunto.csv
#
# Archivo Alexa Startup Ideas_subconjunto.csv de 1637
# Faltan 1578 archivos
#
# DataFrame con palabras clave para Algorithm Startup Ideas_subconjunto.csv
#
# Archivo Algorithm Startup Ideas_subconjunto.csv de 1637
# Faltan 1577 archivos
#
# DataFrame con palabras clave para Along Startup Ideas_subconjunto.csv
#
# Archivo Along Startup Ideas_subconjunto.csv de 1637
# Faltan 1576 archivos
#
# DataFrame con palabras clave para Alternative Startup Ideas_subconjunto.csv
#
# Archivo Alternative Startup Ideas_subconjunto.csv de 1637
# Faltan 1575 archivos
#
# DataFrame con palabras clave para Alum Startup Ideas_subconjunto.csv
#
# Archivo Alum Startup Ideas_subconjunto.csv de 1637
# Faltan 1574 archivos
#
# DataFrame con palabras clave para Amazon Startup Ideas_subconjunto.csv
#
# Archivo Amazon Startup Ideas_subconjunto.csv de 1637
# Faltan 1573 archivos
#
# DataFrame con palabras clave para America Startup Ideas_subconjunto.csv
#
# Archivo America Startup Ideas_subconjunto.csv de 1637
# Faltan 1572 archivos
#
# DataFrame con palabras clave para American Startup Ideas_subconjunto.csv
#
# Archivo American Startup Ideas_subconjunto.csv de 1637
# Faltan 1571 archivos
#
# DataFrame con palabras clave para Among Startup Ideas_subconjunto.csv
#
# Archivo Among Startup Ideas_subconjunto.csv de 1637
# Faltan 1570 archivos
#
# DataFrame con palabras clave para Amount Startup Ideas_subconjunto.csv
#
# Archivo Amount Startup Ideas_subconjunto.csv de 1637
# Faltan 1569 archivos
#
# DataFrame con palabras clave para Analyze Startup Ideas_subconjunto.csv
#
# Archivo Analyze Startup Ideas_subconjunto.csv de 1637
# Faltan 1568 archivos
#
# DataFrame con palabras clave para Analyzing Startup Ideas_subconjunto.csv
#
# Archivo Analyzing Startup Ideas_subconjunto.csv de 1637
# Faltan 1567 archivos
#
# DataFrame con palabras clave para Andreessen Startup Ideas_subconjunto.csv
#
# Archivo Andreessen Startup Ideas_subconjunto.csv de 1637
# Faltan 1566 archivos
#
# DataFrame con palabras clave para Android Startup Ideas_subconjunto.csv
#
# Archivo Android Startup Ideas_subconjunto.csv de 1637
# Faltan 1565 archivos
#
# DataFrame con palabras clave para Angel Startup Ideas_subconjunto.csv
#
# Archivo Angel Startup Ideas_subconjunto.csv de 1637
# Faltan 1564 archivos
#
# DataFrame con palabras clave para Announced Startup Ideas_subconjunto.csv
#
# Archivo Announced Startup Ideas_subconjunto.csv de 1637
# Faltan 1563 archivos
#
# DataFrame con palabras clave para Annual Startup Ideas_subconjunto.csv
#
# Archivo Annual Startup Ideas_subconjunto.csv de 1637
# Faltan 1562 archivos
#
# DataFrame con palabras clave para Another Startup Ideas_subconjunto.csv
#
# Archivo Another Startup Ideas_subconjunto.csv de 1637
# Faltan 1561 archivos
#
# DataFrame con palabras clave para Answer Startup Ideas_subconjunto.csv
#
# Archivo Answer Startup Ideas_subconjunto.csv de 1637
# Faltan 1560 archivos
#
# DataFrame con palabras clave para Anxiety Startup Ideas_subconjunto.csv
#
# Archivo Anxiety Startup Ideas_subconjunto.csv de 1637
# Faltan 1559 archivos
#
# DataFrame con palabras clave para Anyone Startup Ideas_subconjunto.csv
#
# Archivo Anyone Startup Ideas_subconjunto.csv de 1637
# Faltan 1558 archivos
#
# DataFrame con palabras clave para Anything Startup Ideas_subconjunto.csv
#
# Archivo Anything Startup Ideas_subconjunto.csv de 1637
# Faltan 1557 archivos
#
# DataFrame con palabras clave para Anywhere Startup Ideas_subconjunto.csv
#
# Archivo Anywhere Startup Ideas_subconjunto.csv de 1637
# Faltan 1556 archivos
#
# DataFrame con palabras clave para Apartment Startup Ideas_subconjunto.csv
#
# Archivo Apartment Startup Ideas_subconjunto.csv de 1637
# Faltan 1555 archivos
#
# DataFrame con palabras clave para Api Startup Ideas_subconjunto.csv
#
# Archivo Api Startup Ideas_subconjunto.csv de 1637
# Faltan 1554 archivos
#
# DataFrame con palabras clave para App Startup Ideas_subconjunto.csv
#
# Archivo App Startup Ideas_subconjunto.csv de 1637
# Faltan 1553 archivos
#
# DataFrame con palabras clave para Apple Startup Ideas_subconjunto.csv
#
# Archivo Apple Startup Ideas_subconjunto.csv de 1637
# Faltan 1552 archivos
#
# DataFrame con palabras clave para Application Startup Ideas_subconjunto.csv
#
# Archivo Application Startup Ideas_subconjunto.csv de 1637
# Faltan 1551 archivos
#
# DataFrame con palabras clave para Apply Startup Ideas_subconjunto.csv
#
# Archivo Apply Startup Ideas_subconjunto.csv de 1637
# Faltan 1550 archivos
#
# DataFrame con palabras clave para Applying Startup Ideas_subconjunto.csv
#
# Archivo Applying Startup Ideas_subconjunto.csv de 1637
# Faltan 1549 archivos
#
# DataFrame con palabras clave para Appointment Startup Ideas_subconjunto.csv
#
# Archivo Appointment Startup Ideas_subconjunto.csv de 1637
# Faltan 1548 archivos
#
# DataFrame con palabras clave para Approach Startup Ideas_subconjunto.csv
#
# Archivo Approach Startup Ideas_subconjunto.csv de 1637
# Faltan 1547 archivos
#
# DataFrame con palabras clave para Approved Startup Ideas_subconjunto.csv
#
# Archivo Approved Startup Ideas_subconjunto.csv de 1637
# Faltan 1546 archivos
#
# DataFrame con palabras clave para April Startup Ideas_subconjunto.csv
#
# Archivo April Startup Ideas_subconjunto.csv de 1637
# Faltan 1545 archivos
#
# DataFrame con palabras clave para Ar Startup Ideas_subconjunto.csv
#
# Archivo Ar Startup Ideas_subconjunto.csv de 1637
# Faltan 1544 archivos
#
# DataFrame con palabras clave para Area Startup Ideas_subconjunto.csv
#
# Archivo Area Startup Ideas_subconjunto.csv de 1637
# Faltan 1543 archivos
#
# DataFrame con palabras clave para Arent Startup Ideas_subconjunto.csv
#
# Archivo Arent Startup Ideas_subconjunto.csv de 1637
# Faltan 1542 archivos
#
# DataFrame con palabras clave para Art Startup Ideas_subconjunto.csv
#
# Archivo Art Startup Ideas_subconjunto.csv de 1637
# Faltan 1541 archivos
#
# DataFrame con palabras clave para Article Startup Ideas_subconjunto.csv
#
# Archivo Article Startup Ideas_subconjunto.csv de 1637
# Faltan 1540 archivos
#
# DataFrame con palabras clave para Artificial Startup Ideas_subconjunto.csv
#
# Archivo Artificial Startup Ideas_subconjunto.csv de 1637
# Faltan 1539 archivos
#
# DataFrame con palabras clave para Asia Startup Ideas_subconjunto.csv
#
# Archivo Asia Startup Ideas_subconjunto.csv de 1637
# Faltan 1538 archivos
#
# DataFrame con palabras clave para Ask Startup Ideas_subconjunto.csv
#
# Archivo Ask Startup Ideas_subconjunto.csv de 1637
# Faltan 1537 archivos
#
# DataFrame con palabras clave para Asset Startup Ideas_subconjunto.csv
#
# Archivo Asset Startup Ideas_subconjunto.csv de 1637
# Faltan 1536 archivos
#
# DataFrame con palabras clave para Assistant Startup Ideas_subconjunto.csv
#
# Archivo Assistant Startup Ideas_subconjunto.csv de 1637
# Faltan 1535 archivos
#
# DataFrame con palabras clave para Atm Startup Ideas_subconjunto.csv
#
# Archivo Atm Startup Ideas_subconjunto.csv de 1637
# Faltan 1534 archivos
#
# DataFrame con palabras clave para Attendance Startup Ideas_subconjunto.csv
#
# Archivo Attendance Startup Ideas_subconjunto.csv de 1637
# Faltan 1533 archivos
#
# DataFrame con palabras clave para Attention Startup Ideas_subconjunto.csv
#
# Archivo Attention Startup Ideas_subconjunto.csv de 1637
# Faltan 1532 archivos
#
# DataFrame con palabras clave para Attract Startup Ideas_subconjunto.csv
#
# Archivo Attract Startup Ideas_subconjunto.csv de 1637
# Faltan 1531 archivos
#
# DataFrame con palabras clave para Audience Startup Ideas_subconjunto.csv
#
# Archivo Audience Startup Ideas_subconjunto.csv de 1637
# Faltan 1530 archivos
#
# DataFrame con palabras clave para Audio Startup Ideas_subconjunto.csv
#
# Archivo Audio Startup Ideas_subconjunto.csv de 1637
# Faltan 1529 archivos
#
# DataFrame con palabras clave para Augmented Startup Ideas_subconjunto.csv
#
# Archivo Augmented Startup Ideas_subconjunto.csv de 1637
# Faltan 1528 archivos
#
# DataFrame con palabras clave para August Startup Ideas_subconjunto.csv
#
# Archivo August Startup Ideas_subconjunto.csv de 1637
# Faltan 1527 archivos
#
# DataFrame con palabras clave para Australia Startup Ideas_subconjunto.csv
#
# Archivo Australia Startup Ideas_subconjunto.csv de 1637
# Faltan 1526 archivos
#
# DataFrame con palabras clave para Auto Startup Ideas_subconjunto.csv
#
# Archivo Auto Startup Ideas_subconjunto.csv de 1637
# Faltan 1525 archivos
#
# DataFrame con palabras clave para Automate Startup Ideas_subconjunto.csv
#
# Archivo Automate Startup Ideas_subconjunto.csv de 1637
# Faltan 1524 archivos
#
# DataFrame con palabras clave para Automated Startup Ideas_subconjunto.csv
#
# Archivo Automated Startup Ideas_subconjunto.csv de 1637
# Faltan 1523 archivos
#
# DataFrame con palabras clave para Automatic Startup Ideas_subconjunto.csv
#
# Archivo Automatic Startup Ideas_subconjunto.csv de 1637
# Faltan 1522 archivos
#
# DataFrame con palabras clave para Automating Startup Ideas_subconjunto.csv
#
# Archivo Automating Startup Ideas_subconjunto.csv de 1637
# Faltan 1521 archivos
#
# DataFrame con palabras clave para Automation Startup Ideas_subconjunto.csv
#
# Archivo Automation Startup Ideas_subconjunto.csv de 1637
# Faltan 1520 archivos
#
# DataFrame con palabras clave para Available Startup Ideas_subconjunto.csv
#
# Archivo Available Startup Ideas_subconjunto.csv de 1637
# Faltan 1519 archivos
#
# DataFrame con palabras clave para Average Startup Ideas_subconjunto.csv
#
# Archivo Average Startup Ideas_subconjunto.csv de 1637
# Faltan 1518 archivos
#
# DataFrame con palabras clave para Avoid Startup Ideas_subconjunto.csv
#
# Archivo Avoid Startup Ideas_subconjunto.csv de 1637
# Faltan 1517 archivos
#
# DataFrame con palabras clave para Away Startup Ideas_subconjunto.csv
#
# Archivo Away Startup Ideas_subconjunto.csv de 1637
# Faltan 1516 archivos
#
# DataFrame con palabras clave para B Startup Ideas_subconjunto.csv
#
# Archivo B Startup Ideas_subconjunto.csv de 1637
# Faltan 1515 archivos
#
# DataFrame con palabras clave para B2b Startup Ideas_subconjunto.csv
#
# Archivo B2b Startup Ideas_subconjunto.csv de 1637
# Faltan 1514 archivos
#
# DataFrame con palabras clave para B2c Startup Ideas_subconjunto.csv
#
# Archivo B2c Startup Ideas_subconjunto.csv de 1637
# Faltan 1513 archivos
#
# DataFrame con palabras clave para Backed Startup Ideas_subconjunto.csv
#
# Archivo Backed Startup Ideas_subconjunto.csv de 1637
# Faltan 1512 archivos
#
# DataFrame con palabras clave para Backend Startup Ideas_subconjunto.csv
#
# Archivo Backend Startup Ideas_subconjunto.csv de 1637
# Faltan 1511 archivos
#
# DataFrame con palabras clave para Background Startup Ideas_subconjunto.csv
#
# Archivo Background Startup Ideas_subconjunto.csv de 1637
# Faltan 1510 archivos
#
# DataFrame con palabras clave para Bad Startup Ideas_subconjunto.csv
#
# Archivo Bad Startup Ideas_subconjunto.csv de 1637
# Faltan 1509 archivos
#
# DataFrame con palabras clave para Balance Startup Ideas_subconjunto.csv
#
# Archivo Balance Startup Ideas_subconjunto.csv de 1637
# Faltan 1508 archivos
#
# DataFrame con palabras clave para Band Startup Ideas_subconjunto.csv
#
# Archivo Band Startup Ideas_subconjunto.csv de 1637
# Faltan 1507 archivos
#
# DataFrame con palabras clave para Bank Startup Ideas_subconjunto.csv
#
# Archivo Bank Startup Ideas_subconjunto.csv de 1637
# Faltan 1506 archivos
#
# DataFrame con palabras clave para Banking Startup Ideas_subconjunto.csv
#
# Archivo Banking Startup Ideas_subconjunto.csv de 1637
# Faltan 1505 archivos
#
# DataFrame con palabras clave para Bar Startup Ideas_subconjunto.csv
#
# Archivo Bar Startup Ideas_subconjunto.csv de 1637
# Faltan 1504 archivos
#
# DataFrame con palabras clave para Barcode Startup Ideas_subconjunto.csv
#
# Archivo Barcode Startup Ideas_subconjunto.csv de 1637
# Faltan 1503 archivos
#
# DataFrame con palabras clave para Base Startup Ideas_subconjunto.csv
#
# Archivo Base Startup Ideas_subconjunto.csv de 1637
# Faltan 1502 archivos
#
# DataFrame con palabras clave para Based Startup Ideas_subconjunto.csv
#
# Archivo Based Startup Ideas_subconjunto.csv de 1637
# Faltan 1501 archivos
#
# DataFrame con palabras clave para Basic Startup Ideas_subconjunto.csv
#
# Archivo Basic Startup Ideas_subconjunto.csv de 1637
# Faltan 1500 archivos
#
# DataFrame con palabras clave para Basically Startup Ideas_subconjunto.csv
#
# Archivo Basically Startup Ideas_subconjunto.csv de 1637
# Faltan 1499 archivos
#
# DataFrame con palabras clave para Batch Startup Ideas_subconjunto.csv
#
# Archivo Batch Startup Ideas_subconjunto.csv de 1637
# Faltan 1498 archivos
#
# DataFrame con palabras clave para Battery Startup Ideas_subconjunto.csv
#
# Archivo Battery Startup Ideas_subconjunto.csv de 1637
# Faltan 1497 archivos
#
# DataFrame con palabras clave para Bay Startup Ideas_subconjunto.csv
#
# Archivo Bay Startup Ideas_subconjunto.csv de 1637
# Faltan 1496 archivos
#
# DataFrame con palabras clave para Beautiful Startup Ideas_subconjunto.csv
#
# Archivo Beautiful Startup Ideas_subconjunto.csv de 1637
# Faltan 1495 archivos
#
# DataFrame con palabras clave para Beauty Startup Ideas_subconjunto.csv
#
# Archivo Beauty Startup Ideas_subconjunto.csv de 1637
# Faltan 1494 archivos
#
# DataFrame con palabras clave para Become Startup Ideas_subconjunto.csv
#
# Archivo Become Startup Ideas_subconjunto.csv de 1637
# Faltan 1493 archivos
#
# DataFrame con palabras clave para Been Startup Ideas_subconjunto.csv
#
# Archivo Been Startup Ideas_subconjunto.csv de 1637
# Faltan 1492 archivos
#
# DataFrame con palabras clave para Beer Startup Ideas_subconjunto.csv
#
# Archivo Beer Startup Ideas_subconjunto.csv de 1637
# Faltan 1491 archivos
#
# DataFrame con palabras clave para Before Startup Ideas_subconjunto.csv
#
# Archivo Before Startup Ideas_subconjunto.csv de 1637
# Faltan 1490 archivos
#
# DataFrame con palabras clave para Behalf Startup Ideas_subconjunto.csv
#
# Archivo Behalf Startup Ideas_subconjunto.csv de 1637
# Faltan 1489 archivos
#
# DataFrame con palabras clave para Behavior Startup Ideas_subconjunto.csv
#
# Archivo Behavior Startup Ideas_subconjunto.csv de 1637
# Faltan 1488 archivos
#
# DataFrame con palabras clave para Behavioral Startup Ideas_subconjunto.csv
#
# Archivo Behavioral Startup Ideas_subconjunto.csv de 1637
# Faltan 1487 archivos
#
# DataFrame con palabras clave para Behind Startup Ideas_subconjunto.csv
#
# Archivo Behind Startup Ideas_subconjunto.csv de 1637
# Faltan 1486 archivos
#
# DataFrame con palabras clave para Being Startup Ideas_subconjunto.csv
#
# Archivo Being Startup Ideas_subconjunto.csv de 1637
# Faltan 1485 archivos
#
# DataFrame con palabras clave para Best Startup Ideas_subconjunto.csv
#
# Archivo Best Startup Ideas_subconjunto.csv de 1637
# Faltan 1484 archivos
#
# DataFrame con palabras clave para Beta Startup Ideas_subconjunto.csv
#
# Archivo Beta Startup Ideas_subconjunto.csv de 1637
# Faltan 1483 archivos
#
# DataFrame con palabras clave para Beyond Startup Ideas_subconjunto.csv
#
# Archivo Beyond Startup Ideas_subconjunto.csv de 1637
# Faltan 1482 archivos
#
# DataFrame con palabras clave para Bid Startup Ideas_subconjunto.csv
#
# Archivo Bid Startup Ideas_subconjunto.csv de 1637
# Faltan 1481 archivos
#
# DataFrame con palabras clave para Big Startup Ideas_subconjunto.csv
#
# Archivo Big Startup Ideas_subconjunto.csv de 1637
# Faltan 1480 archivos
#
# DataFrame con palabras clave para Biggest Startup Ideas_subconjunto.csv
#
# Archivo Biggest Startup Ideas_subconjunto.csv de 1637
# Faltan 1479 archivos
#
# DataFrame con palabras clave para Bike Startup Ideas_subconjunto.csv
#
# Archivo Bike Startup Ideas_subconjunto.csv de 1637
# Faltan 1478 archivos
#
# DataFrame con palabras clave para Bill Startup Ideas_subconjunto.csv
#
# Archivo Bill Startup Ideas_subconjunto.csv de 1637
# Faltan 1477 archivos
#
# DataFrame con palabras clave para Billing Startup Ideas_subconjunto.csv
#
# Archivo Billing Startup Ideas_subconjunto.csv de 1637
# Faltan 1476 archivos
#
# DataFrame con palabras clave para Billion Startup Ideas_subconjunto.csv
#
# Archivo Billion Startup Ideas_subconjunto.csv de 1637
# Faltan 1475 archivos
#
# DataFrame con palabras clave para Bit Startup Ideas_subconjunto.csv
#
# Archivo Bit Startup Ideas_subconjunto.csv de 1637
# Faltan 1474 archivos
#
# DataFrame con palabras clave para Bitcoin Startup Ideas_subconjunto.csv
#
# Archivo Bitcoin Startup Ideas_subconjunto.csv de 1637
# Faltan 1473 archivos
#
# DataFrame con palabras clave para Blind Startup Ideas_subconjunto.csv
#
# Archivo Blind Startup Ideas_subconjunto.csv de 1637
# Faltan 1472 archivos
#
# DataFrame con palabras clave para Blockchain Startup Ideas_subconjunto.csv
#
# Archivo Blockchain Startup Ideas_subconjunto.csv de 1637
# Faltan 1471 archivos
#
# DataFrame con palabras clave para Blog Startup Ideas_subconjunto.csv
#
# Archivo Blog Startup Ideas_subconjunto.csv de 1637
# Faltan 1470 archivos
#
# DataFrame con palabras clave para Blood Startup Ideas_subconjunto.csv
#
# Archivo Blood Startup Ideas_subconjunto.csv de 1637
# Faltan 1469 archivos
#
# DataFrame con palabras clave para Bluetooth Startup Ideas_subconjunto.csv
#
# Archivo Bluetooth Startup Ideas_subconjunto.csv de 1637
# Faltan 1468 archivos
#
# DataFrame con palabras clave para Board Startup Ideas_subconjunto.csv
#
# Archivo Board Startup Ideas_subconjunto.csv de 1637
# Faltan 1467 archivos
#
# DataFrame con palabras clave para Body Startup Ideas_subconjunto.csv
#
# Archivo Body Startup Ideas_subconjunto.csv de 1637
# Faltan 1466 archivos
#
# DataFrame con palabras clave para Book Startup Ideas_subconjunto.csv
#
# Archivo Book Startup Ideas_subconjunto.csv de 1637
# Faltan 1465 archivos
#
# DataFrame con palabras clave para Booking Startup Ideas_subconjunto.csv
#
# Archivo Booking Startup Ideas_subconjunto.csv de 1637
# Faltan 1464 archivos
#
# DataFrame con palabras clave para Bookkeeping Startup Ideas_subconjunto.csv
#
# Archivo Bookkeeping Startup Ideas_subconjunto.csv de 1637
# Faltan 1463 archivos
#
# DataFrame con palabras clave para Borrow Startup Ideas_subconjunto.csv
#
# Archivo Borrow Startup Ideas_subconjunto.csv de 1637
# Faltan 1462 archivos
#
# DataFrame con palabras clave para Boston Startup Ideas_subconjunto.csv
#
# Archivo Boston Startup Ideas_subconjunto.csv de 1637
# Faltan 1461 archivos
#
# DataFrame con palabras clave para Bot Startup Ideas_subconjunto.csv
#
# Archivo Bot Startup Ideas_subconjunto.csv de 1637
# Faltan 1460 archivos
#
# DataFrame con palabras clave para Both Startup Ideas_subconjunto.csv
#
# Archivo Both Startup Ideas_subconjunto.csv de 1637
# Faltan 1459 archivos
#
# DataFrame con palabras clave para Bought Startup Ideas_subconjunto.csv
#
# Archivo Bought Startup Ideas_subconjunto.csv de 1637
# Faltan 1458 archivos
#
# DataFrame con palabras clave para Box Startup Ideas_subconjunto.csv
#
# Archivo Box Startup Ideas_subconjunto.csv de 1637
# Faltan 1457 archivos
#
# DataFrame con palabras clave para Brain Startup Ideas_subconjunto.csv
#
# Archivo Brain Startup Ideas_subconjunto.csv de 1637
# Faltan 1456 archivos
#
# DataFrame con palabras clave para Brand Startup Ideas_subconjunto.csv
#
# Archivo Brand Startup Ideas_subconjunto.csv de 1637
# Faltan 1455 archivos
#
# DataFrame con palabras clave para Branded Startup Ideas_subconjunto.csv
#
# Archivo Branded Startup Ideas_subconjunto.csv de 1637
# Faltan 1454 archivos
#
# DataFrame con palabras clave para Brazil Startup Ideas_subconjunto.csv
#
# Archivo Brazil Startup Ideas_subconjunto.csv de 1637
# Faltan 1453 archivos
#
# DataFrame con palabras clave para Break Startup Ideas_subconjunto.csv
#
# Archivo Break Startup Ideas_subconjunto.csv de 1637
# Faltan 1452 archivos
#
# DataFrame con palabras clave para Brick Startup Ideas_subconjunto.csv
#
# Archivo Brick Startup Ideas_subconjunto.csv de 1637
# Faltan 1451 archivos
#
# DataFrame con palabras clave para Bridge Startup Ideas_subconjunto.csv
#
# Archivo Bridge Startup Ideas_subconjunto.csv de 1637
# Faltan 1450 archivos
#
# DataFrame con palabras clave para Bring Startup Ideas_subconjunto.csv
#
# Archivo Bring Startup Ideas_subconjunto.csv de 1637
# Faltan 1449 archivos
#
# DataFrame con palabras clave para Bringing Startup Ideas_subconjunto.csv
#
# Archivo Bringing Startup Ideas_subconjunto.csv de 1637
# Faltan 1448 archivos
#
# DataFrame con palabras clave para Broadcast Startup Ideas_subconjunto.csv
#
# Archivo Broadcast Startup Ideas_subconjunto.csv de 1637
# Faltan 1447 archivos
#
# DataFrame con palabras clave para Broker Startup Ideas_subconjunto.csv
#
# Archivo Broker Startup Ideas_subconjunto.csv de 1637
# Faltan 1446 archivos
#
# DataFrame con palabras clave para Browse Startup Ideas_subconjunto.csv
#
# Archivo Browse Startup Ideas_subconjunto.csv de 1637
# Faltan 1445 archivos
#
# DataFrame con palabras clave para Browser Startup Ideas_subconjunto.csv
#
# Archivo Browser Startup Ideas_subconjunto.csv de 1637
# Faltan 1444 archivos
#
# DataFrame con palabras clave para Budget Startup Ideas_subconjunto.csv
#
# Archivo Budget Startup Ideas_subconjunto.csv de 1637
# Faltan 1443 archivos
#
# DataFrame con palabras clave para Budgeting Startup Ideas_subconjunto.csv
#
# Archivo Budgeting Startup Ideas_subconjunto.csv de 1637
# Faltan 1442 archivos
#
# DataFrame con palabras clave para Build Startup Ideas_subconjunto.csv
#
# Archivo Build Startup Ideas_subconjunto.csv de 1637
# Faltan 1441 archivos
#
# DataFrame con palabras clave para Builder Startup Ideas_subconjunto.csv
#
# Archivo Builder Startup Ideas_subconjunto.csv de 1637
# Faltan 1440 archivos
#
# DataFrame con palabras clave para Bulk Startup Ideas_subconjunto.csv
#
# Archivo Bulk Startup Ideas_subconjunto.csv de 1637
# Faltan 1439 archivos
#
# DataFrame con palabras clave para Bunch Startup Ideas_subconjunto.csv
#
# Archivo Bunch Startup Ideas_subconjunto.csv de 1637
# Faltan 1438 archivos
#
# DataFrame con palabras clave para Busy Startup Ideas_subconjunto.csv
#
# Archivo Busy Startup Ideas_subconjunto.csv de 1637
# Faltan 1437 archivos
#
# DataFrame con palabras clave para Button Startup Ideas_subconjunto.csv
#
# Archivo Button Startup Ideas_subconjunto.csv de 1637
# Faltan 1436 archivos
#
# DataFrame con palabras clave para Buyer Startup Ideas_subconjunto.csv
#
# Archivo Buyer Startup Ideas_subconjunto.csv de 1637
# Faltan 1435 archivos
#
# DataFrame con palabras clave para Buying Startup Ideas_subconjunto.csv
#
# Archivo Buying Startup Ideas_subconjunto.csv de 1637
# Faltan 1434 archivos
#
# DataFrame con palabras clave para Calculate Startup Ideas_subconjunto.csv
#
# Archivo Calculate Startup Ideas_subconjunto.csv de 1637
# Faltan 1433 archivos
#
# DataFrame con palabras clave para Calendar Startup Ideas_subconjunto.csv
#
# Archivo Calendar Startup Ideas_subconjunto.csv de 1637
# Faltan 1432 archivos
#
# DataFrame con palabras clave para California Startup Ideas_subconjunto.csv
#
# Archivo California Startup Ideas_subconjunto.csv de 1637
# Faltan 1431 archivos
#
# DataFrame con palabras clave para Call Startup Ideas_subconjunto.csv
#
# Archivo Call Startup Ideas_subconjunto.csv de 1637
# Faltan 1430 archivos
#
# DataFrame con palabras clave para Called Startup Ideas_subconjunto.csv
#
# Archivo Called Startup Ideas_subconjunto.csv de 1637
# Faltan 1429 archivos
#
# DataFrame con palabras clave para Calling Startup Ideas_subconjunto.csv
#
# Archivo Calling Startup Ideas_subconjunto.csv de 1637
# Faltan 1428 archivos
#
# DataFrame con palabras clave para Camera Startup Ideas_subconjunto.csv
#
# Archivo Camera Startup Ideas_subconjunto.csv de 1637
# Faltan 1427 archivos
#
# DataFrame con palabras clave para Campaign Startup Ideas_subconjunto.csv
#
# Archivo Campaign Startup Ideas_subconjunto.csv de 1637
# Faltan 1426 archivos
#
# DataFrame con palabras clave para Canada Startup Ideas_subconjunto.csv
#
# Archivo Canada Startup Ideas_subconjunto.csv de 1637
# Faltan 1425 archivos
#
# DataFrame con palabras clave para Cancer Startup Ideas_subconjunto.csv
#
# Archivo Cancer Startup Ideas_subconjunto.csv de 1637
# Faltan 1424 archivos
#
# DataFrame con palabras clave para Candidate Startup Ideas_subconjunto.csv
#
# Archivo Candidate Startup Ideas_subconjunto.csv de 1637
# Faltan 1423 archivos
#
# DataFrame con palabras clave para Cant Startup Ideas_subconjunto.csv
#
# Archivo Cant Startup Ideas_subconjunto.csv de 1637
# Faltan 1422 archivos
#
# DataFrame con palabras clave para Capital Startup Ideas_subconjunto.csv
#
# Archivo Capital Startup Ideas_subconjunto.csv de 1637
# Faltan 1421 archivos
#
# DataFrame con palabras clave para Capture Startup Ideas_subconjunto.csv
#
# Archivo Capture Startup Ideas_subconjunto.csv de 1637
# Faltan 1420 archivos
#
# DataFrame con palabras clave para Car Startup Ideas_subconjunto.csv
#
# Archivo Car Startup Ideas_subconjunto.csv de 1637
# Faltan 1419 archivos
#
# DataFrame con palabras clave para Carbon Startup Ideas_subconjunto.csv
#
# Archivo Carbon Startup Ideas_subconjunto.csv de 1637
# Faltan 1418 archivos
#
# DataFrame con palabras clave para Card Startup Ideas_subconjunto.csv
#
# Archivo Card Startup Ideas_subconjunto.csv de 1637
# Faltan 1417 archivos
#
# DataFrame con palabras clave para Care Startup Ideas_subconjunto.csv
#
# Archivo Care Startup Ideas_subconjunto.csv de 1637
# Faltan 1416 archivos
#
# DataFrame con palabras clave para Career Startup Ideas_subconjunto.csv
#
# Archivo Career Startup Ideas_subconjunto.csv de 1637
# Faltan 1415 archivos
#
# DataFrame con palabras clave para Carpooling Startup Ideas_subconjunto.csv
#
# Archivo Carpooling Startup Ideas_subconjunto.csv de 1637
# Faltan 1414 archivos
#
# DataFrame con palabras clave para Cart Startup Ideas_subconjunto.csv
#
# Archivo Cart Startup Ideas_subconjunto.csv de 1637
# Faltan 1413 archivos
#
# DataFrame con palabras clave para Case Startup Ideas_subconjunto.csv
#
# Archivo Case Startup Ideas_subconjunto.csv de 1637
# Faltan 1412 archivos
#
# DataFrame con palabras clave para Cash Startup Ideas_subconjunto.csv
#
# Archivo Cash Startup Ideas_subconjunto.csv de 1637
# Faltan 1411 archivos
#
# DataFrame con palabras clave para Category Startup Ideas_subconjunto.csv
#
# Archivo Category Startup Ideas_subconjunto.csv de 1637
# Faltan 1410 archivos
#
# DataFrame con palabras clave para Cause Startup Ideas_subconjunto.csv
#
# Archivo Cause Startup Ideas_subconjunto.csv de 1637
# Faltan 1409 archivos
#
# DataFrame con palabras clave para Cell Startup Ideas_subconjunto.csv
#
# Archivo Cell Startup Ideas_subconjunto.csv de 1637
# Faltan 1408 archivos
#
# DataFrame con palabras clave para Center Startup Ideas_subconjunto.csv
#
# Archivo Center Startup Ideas_subconjunto.csv de 1637
# Faltan 1407 archivos
#
# DataFrame con palabras clave para Central Startup Ideas_subconjunto.csv
#
# Archivo Central Startup Ideas_subconjunto.csv de 1637
# Faltan 1406 archivos
#
# DataFrame con palabras clave para Centralized Startup Ideas_subconjunto.csv
#
# Archivo Centralized Startup Ideas_subconjunto.csv de 1637
# Faltan 1405 archivos
#
# DataFrame con palabras clave para Ceo Startup Ideas_subconjunto.csv
#
# Archivo Ceo Startup Ideas_subconjunto.csv de 1637
# Faltan 1404 archivos
#
# DataFrame con palabras clave para Certain Startup Ideas_subconjunto.csv
#
# Archivo Certain Startup Ideas_subconjunto.csv de 1637
# Faltan 1403 archivos
#
# DataFrame con palabras clave para Chain Startup Ideas_subconjunto.csv
#
# Archivo Chain Startup Ideas_subconjunto.csv de 1637
# Faltan 1402 archivos
#
# DataFrame con palabras clave para Chance Startup Ideas_subconjunto.csv
#
# Archivo Chance Startup Ideas_subconjunto.csv de 1637
# Faltan 1401 archivos
#
# DataFrame con palabras clave para Change Startup Ideas_subconjunto.csv
#
# Archivo Change Startup Ideas_subconjunto.csv de 1637
# Faltan 1400 archivos
#
# DataFrame con palabras clave para Changing Startup Ideas_subconjunto.csv
#
# Archivo Changing Startup Ideas_subconjunto.csv de 1637
# Faltan 1399 archivos
#
# DataFrame con palabras clave para Channel Startup Ideas_subconjunto.csv
#
# Archivo Channel Startup Ideas_subconjunto.csv de 1637
# Faltan 1398 archivos
#
# DataFrame con palabras clave para Charge Startup Ideas_subconjunto.csv
#
# Archivo Charge Startup Ideas_subconjunto.csv de 1637
# Faltan 1397 archivos
#
# DataFrame con palabras clave para Charging Startup Ideas_subconjunto.csv
#
# Archivo Charging Startup Ideas_subconjunto.csv de 1637
# Faltan 1396 archivos
#
# DataFrame con palabras clave para Charity Startup Ideas_subconjunto.csv
#
# Archivo Charity Startup Ideas_subconjunto.csv de 1637
# Faltan 1395 archivos
#
# DataFrame con palabras clave para Chat Startup Ideas_subconjunto.csv
#
# Archivo Chat Startup Ideas_subconjunto.csv de 1637
# Faltan 1394 archivos
#
# DataFrame con palabras clave para Chatbot Startup Ideas_subconjunto.csv
#
# Archivo Chatbot Startup Ideas_subconjunto.csv de 1637
# Faltan 1393 archivos
#
# DataFrame con palabras clave para Cheap Startup Ideas_subconjunto.csv
#
# Archivo Cheap Startup Ideas_subconjunto.csv de 1637
# Faltan 1392 archivos
#
# DataFrame con palabras clave para Cheaper Startup Ideas_subconjunto.csv
#
# Archivo Cheaper Startup Ideas_subconjunto.csv de 1637
# Faltan 1391 archivos
#
# DataFrame con palabras clave para Cheapest Startup Ideas_subconjunto.csv
#
# Archivo Cheapest Startup Ideas_subconjunto.csv de 1637
# Faltan 1390 archivos
#
# DataFrame con palabras clave para Check Startup Ideas_subconjunto.csv
#
# Archivo Check Startup Ideas_subconjunto.csv de 1637
# Faltan 1389 archivos
#
# DataFrame con palabras clave para Checking Startup Ideas_subconjunto.csv
#
# Archivo Checking Startup Ideas_subconjunto.csv de 1637
# Faltan 1388 archivos
#
# DataFrame con palabras clave para Checkout Startup Ideas_subconjunto.csv
#
# Archivo Checkout Startup Ideas_subconjunto.csv de 1637
# Faltan 1387 archivos
#
# DataFrame con palabras clave para Chicago Startup Ideas_subconjunto.csv
#
# Archivo Chicago Startup Ideas_subconjunto.csv de 1637
# Faltan 1386 archivos
#
# DataFrame con palabras clave para Child Startup Ideas_subconjunto.csv
#
# Archivo Child Startup Ideas_subconjunto.csv de 1637
# Faltan 1385 archivos
#
# DataFrame con palabras clave para Children Startup Ideas_subconjunto.csv
#
# Archivo Children Startup Ideas_subconjunto.csv de 1637
# Faltan 1384 archivos
#
# DataFrame con palabras clave para China Startup Ideas_subconjunto.csv
#
# Archivo China Startup Ideas_subconjunto.csv de 1637
# Faltan 1383 archivos
#
# DataFrame con palabras clave para Chinese Startup Ideas_subconjunto.csv
#
# Archivo Chinese Startup Ideas_subconjunto.csv de 1637
# Faltan 1382 archivos
#
# DataFrame con palabras clave para Choice Startup Ideas_subconjunto.csv
#
# Archivo Choice Startup Ideas_subconjunto.csv de 1637
# Faltan 1381 archivos
#
# DataFrame con palabras clave para Choose Startup Ideas_subconjunto.csv
#
# Archivo Choose Startup Ideas_subconjunto.csv de 1637
# Faltan 1380 archivos
#
# DataFrame con palabras clave para Chrome Startup Ideas_subconjunto.csv
#
# Archivo Chrome Startup Ideas_subconjunto.csv de 1637
# Faltan 1379 archivos
#
# DataFrame con palabras clave para Chronic Startup Ideas_subconjunto.csv
#
# Archivo Chronic Startup Ideas_subconjunto.csv de 1637
# Faltan 1378 archivos
#
# DataFrame con palabras clave para City Startup Ideas_subconjunto.csv
#
# Archivo City Startup Ideas_subconjunto.csv de 1637
# Faltan 1377 archivos
#
# DataFrame con palabras clave para Claim Startup Ideas_subconjunto.csv
#
# Archivo Claim Startup Ideas_subconjunto.csv de 1637
# Faltan 1376 archivos
#
# DataFrame con palabras clave para Classroom Startup Ideas_subconjunto.csv
#
# Archivo Classroom Startup Ideas_subconjunto.csv de 1637
# Faltan 1375 archivos
#
# DataFrame con palabras clave para Clean Startup Ideas_subconjunto.csv
#
# Archivo Clean Startup Ideas_subconjunto.csv de 1637
# Faltan 1374 archivos
#
# DataFrame con palabras clave para Cleaning Startup Ideas_subconjunto.csv
#
# Archivo Cleaning Startup Ideas_subconjunto.csv de 1637
# Faltan 1373 archivos
#
# DataFrame con palabras clave para Clear Startup Ideas_subconjunto.csv
#
# Archivo Clear Startup Ideas_subconjunto.csv de 1637
# Faltan 1372 archivos
#
# DataFrame con palabras clave para Click Startup Ideas_subconjunto.csv
#
# Archivo Click Startup Ideas_subconjunto.csv de 1637
# Faltan 1371 archivos
#
# DataFrame con palabras clave para Client Startup Ideas_subconjunto.csv
#
# Archivo Client Startup Ideas_subconjunto.csv de 1637
# Faltan 1370 archivos
#
# DataFrame con palabras clave para Clinical Startup Ideas_subconjunto.csv
#
# Archivo Clinical Startup Ideas_subconjunto.csv de 1637
# Faltan 1369 archivos
#
# DataFrame con palabras clave para Close Startup Ideas_subconjunto.csv
#
# Archivo Close Startup Ideas_subconjunto.csv de 1637
# Faltan 1368 archivos
#
# DataFrame con palabras clave para Closed Startup Ideas_subconjunto.csv
#
# Archivo Closed Startup Ideas_subconjunto.csv de 1637
# Faltan 1367 archivos
#
# DataFrame con palabras clave para Closest Startup Ideas_subconjunto.csv
#
# Archivo Closest Startup Ideas_subconjunto.csv de 1637
# Faltan 1366 archivos
#
# DataFrame con palabras clave para Clothing Startup Ideas_subconjunto.csv
#
# Archivo Clothing Startup Ideas_subconjunto.csv de 1637
# Faltan 1365 archivos
#
# DataFrame con palabras clave para Cloud Startup Ideas_subconjunto.csv
#
# Archivo Cloud Startup Ideas_subconjunto.csv de 1637
# Faltan 1364 archivos
#
# DataFrame con palabras clave para Co Startup Ideas_subconjunto.csv
#
# Archivo Co Startup Ideas_subconjunto.csv de 1637
# Faltan 1363 archivos
#
# DataFrame con palabras clave para Coach Startup Ideas_subconjunto.csv
#
# Archivo Coach Startup Ideas_subconjunto.csv de 1637
# Faltan 1362 archivos
#
# DataFrame con palabras clave para Coaching Startup Ideas_subconjunto.csv
#
# Archivo Coaching Startup Ideas_subconjunto.csv de 1637
# Faltan 1361 archivos
#
# DataFrame con palabras clave para Code Startup Ideas_subconjunto.csv
#
# Archivo Code Startup Ideas_subconjunto.csv de 1637
# Faltan 1360 archivos
#
# DataFrame con palabras clave para Coding Startup Ideas_subconjunto.csv
#
# Archivo Coding Startup Ideas_subconjunto.csv de 1637
# Faltan 1359 archivos
#
# DataFrame con palabras clave para Coffee Startup Ideas_subconjunto.csv
#
# Archivo Coffee Startup Ideas_subconjunto.csv de 1637
# Faltan 1358 archivos
#
# DataFrame con palabras clave para Collaborate Startup Ideas_subconjunto.csv
#
# Archivo Collaborate Startup Ideas_subconjunto.csv de 1637
# Faltan 1357 archivos
#
# DataFrame con palabras clave para Collaboration Startup Ideas_subconjunto.csv
#
# Archivo Collaboration Startup Ideas_subconjunto.csv de 1637
# Faltan 1356 archivos
#
# DataFrame con palabras clave para Collaborative Startup Ideas_subconjunto.csv
#
# Archivo Collaborative Startup Ideas_subconjunto.csv de 1637
# Faltan 1355 archivos
#
# DataFrame con palabras clave para Collect Startup Ideas_subconjunto.csv
#
# Archivo Collect Startup Ideas_subconjunto.csv de 1637
# Faltan 1354 archivos
#
# DataFrame con palabras clave para Collecting Startup Ideas_subconjunto.csv
#
# Archivo Collecting Startup Ideas_subconjunto.csv de 1637
# Faltan 1353 archivos
#
# DataFrame con palabras clave para Collection Startup Ideas_subconjunto.csv
#
# Archivo Collection Startup Ideas_subconjunto.csv de 1637
# Faltan 1352 archivos
#
# DataFrame con palabras clave para College Startup Ideas_subconjunto.csv
#
# Archivo College Startup Ideas_subconjunto.csv de 1637
# Faltan 1351 archivos
#
# DataFrame con palabras clave para Color Startup Ideas_subconjunto.csv
#
# Archivo Color Startup Ideas_subconjunto.csv de 1637
# Faltan 1350 archivos
#
# DataFrame con palabras clave para Combination Startup Ideas_subconjunto.csv
#
# Archivo Combination Startup Ideas_subconjunto.csv de 1637
# Faltan 1349 archivos
#
# DataFrame con palabras clave para Combinator Startup Ideas_subconjunto.csv
#
# Archivo Combinator Startup Ideas_subconjunto.csv de 1637
# Faltan 1348 archivos
#
# DataFrame con palabras clave para Combine Startup Ideas_subconjunto.csv
#
# Archivo Combine Startup Ideas_subconjunto.csv de 1637
# Faltan 1347 archivos
#
# DataFrame con palabras clave para Combining Startup Ideas_subconjunto.csv
#
# Archivo Combining Startup Ideas_subconjunto.csv de 1637
# Faltan 1346 archivos
#
# DataFrame con palabras clave para Coming Startup Ideas_subconjunto.csv
#
# Archivo Coming Startup Ideas_subconjunto.csv de 1637
# Faltan 1345 archivos
#
# DataFrame con palabras clave para Commerce Startup Ideas_subconjunto.csv
#
# Archivo Commerce Startup Ideas_subconjunto.csv de 1637
# Faltan 1344 archivos
#
# DataFrame con palabras clave para Commercial Startup Ideas_subconjunto.csv
#
# Archivo Commercial Startup Ideas_subconjunto.csv de 1637
# Faltan 1343 archivos
#
# DataFrame con palabras clave para Commission Startup Ideas_subconjunto.csv
#
# Archivo Commission Startup Ideas_subconjunto.csv de 1637
# Faltan 1342 archivos
#
# DataFrame con palabras clave para Common Startup Ideas_subconjunto.csv
#
# Archivo Common Startup Ideas_subconjunto.csv de 1637
# Faltan 1341 archivos
#
# DataFrame con palabras clave para Communicate Startup Ideas_subconjunto.csv
#
# Archivo Communicate Startup Ideas_subconjunto.csv de 1637
# Faltan 1340 archivos
#
# DataFrame con palabras clave para Communication Startup Ideas_subconjunto.csv
#
# Archivo Communication Startup Ideas_subconjunto.csv de 1637
# Faltan 1339 archivos
#
# DataFrame con palabras clave para Community Startup Ideas_subconjunto.csv
#
# Archivo Community Startup Ideas_subconjunto.csv de 1637
# Faltan 1338 archivos
#
# DataFrame con palabras clave para Company Startup Ideas_subconjunto.csv
#
# Archivo Company Startup Ideas_subconjunto.csv de 1637
# Faltan 1337 archivos
#
# DataFrame con palabras clave para Compare Startup Ideas_subconjunto.csv
#
# Archivo Compare Startup Ideas_subconjunto.csv de 1637
# Faltan 1336 archivos
#
# DataFrame con palabras clave para Compete Startup Ideas_subconjunto.csv
#
# Archivo Compete Startup Ideas_subconjunto.csv de 1637
# Faltan 1335 archivos
#
# DataFrame con palabras clave para Competitor Startup Ideas_subconjunto.csv
#
# Archivo Competitor Startup Ideas_subconjunto.csv de 1637
# Faltan 1334 archivos
#
# DataFrame con palabras clave para Complete Startup Ideas_subconjunto.csv
#
# Archivo Complete Startup Ideas_subconjunto.csv de 1637
# Faltan 1333 archivos
#
# DataFrame con palabras clave para Complex Startup Ideas_subconjunto.csv
#
# Archivo Complex Startup Ideas_subconjunto.csv de 1637
# Faltan 1332 archivos
#
# DataFrame con palabras clave para Compliance Startup Ideas_subconjunto.csv
#
# Archivo Compliance Startup Ideas_subconjunto.csv de 1637
# Faltan 1331 archivos
#
# DataFrame con palabras clave para Complicated Startup Ideas_subconjunto.csv
#
# Archivo Complicated Startup Ideas_subconjunto.csv de 1637
# Faltan 1330 archivos
#
# DataFrame con palabras clave para Comply Startup Ideas_subconjunto.csv
#
# Archivo Comply Startup Ideas_subconjunto.csv de 1637
# Faltan 1329 archivos
#
# DataFrame con palabras clave para Component Startup Ideas_subconjunto.csv
#
# Archivo Component Startup Ideas_subconjunto.csv de 1637
# Faltan 1328 archivos
#
# DataFrame con palabras clave para Comprehensive Startup Ideas_subconjunto.csv
#
# Archivo Comprehensive Startup Ideas_subconjunto.csv de 1637
# Faltan 1327 archivos
#
# DataFrame con palabras clave para Computer Startup Ideas_subconjunto.csv
#
# Archivo Computer Startup Ideas_subconjunto.csv de 1637
# Faltan 1326 archivos
#
# DataFrame con palabras clave para Computing Startup Ideas_subconjunto.csv
#
# Archivo Computing Startup Ideas_subconjunto.csv de 1637
# Faltan 1325 archivos
#
# DataFrame con palabras clave para Concept Startup Ideas_subconjunto.csv
#
# Archivo Concept Startup Ideas_subconjunto.csv de 1637
# Faltan 1324 archivos
#
# DataFrame con palabras clave para Concierge Startup Ideas_subconjunto.csv
#
# Archivo Concierge Startup Ideas_subconjunto.csv de 1637
# Faltan 1323 archivos
#
# DataFrame con palabras clave para Condition Startup Ideas_subconjunto.csv
#
# Archivo Condition Startup Ideas_subconjunto.csv de 1637
# Faltan 1322 archivos
#
# DataFrame con palabras clave para Conduct Startup Ideas_subconjunto.csv
#
# Archivo Conduct Startup Ideas_subconjunto.csv de 1637
# Faltan 1321 archivos
#
# DataFrame con palabras clave para Conference Startup Ideas_subconjunto.csv
#
# Archivo Conference Startup Ideas_subconjunto.csv de 1637
# Faltan 1320 archivos
#
# DataFrame con palabras clave para Conferencing Startup Ideas_subconjunto.csv
#
# Archivo Conferencing Startup Ideas_subconjunto.csv de 1637
# Faltan 1319 archivos
#
# DataFrame con palabras clave para Connected Startup Ideas_subconjunto.csv
#
# Archivo Connected Startup Ideas_subconjunto.csv de 1637
# Faltan 1318 archivos
#
# DataFrame con palabras clave para Connecting Startup Ideas_subconjunto.csv
#
# Archivo Connecting Startup Ideas_subconjunto.csv de 1637
# Faltan 1317 archivos
#
# DataFrame con palabras clave para Connection Startup Ideas_subconjunto.csv
#
# Archivo Connection Startup Ideas_subconjunto.csv de 1637
# Faltan 1316 archivos
#
# DataFrame con palabras clave para Construction Startup Ideas_subconjunto.csv
#
# Archivo Construction Startup Ideas_subconjunto.csv de 1637
# Faltan 1315 archivos
#
# DataFrame con palabras clave para Consulting Startup Ideas_subconjunto.csv
#
# Archivo Consulting Startup Ideas_subconjunto.csv de 1637
# Faltan 1314 archivos
#
# DataFrame con palabras clave para Consumer Startup Ideas_subconjunto.csv
#
# ...
# Faltan 110 archivos
#
# DataFrame con palabras clave para Twist Startup Ideas_subconjunto.csv
#
# Archivo Twist Startup Ideas_subconjunto.csv de 1637
# Faltan 109 archivos
#
# DataFrame con palabras clave para Twitter Startup Ideas_subconjunto.csv
#
# Archivo Twitter Startup Ideas_subconjunto.csv de 1637
# Faltan 108 archivos
#
# DataFrame con palabras clave para Type Startup Ideas_subconjunto.csv
#
# Archivo Type Startup Ideas_subconjunto.csv de 1637
# Faltan 107 archivos
#
# DataFrame con palabras clave para Typically Startup Ideas_subconjunto.csv
#
# Archivo Typically Startup Ideas_subconjunto.csv de 1637
# Faltan 106 archivos
#
# DataFrame con palabras clave para Uber Startup Ideas_subconjunto.csv
#
# Archivo Uber Startup Ideas_subconjunto.csv de 1637
# Faltan 105 archivos
#
# DataFrame con palabras clave para Uk Startup Ideas_subconjunto.csv
#
# Archivo Uk Startup Ideas_subconjunto.csv de 1637
# Faltan 104 archivos
#
# DataFrame con palabras clave para Unbanked Startup Ideas_subconjunto.csv
#
# Archivo Unbanked Startup Ideas_subconjunto.csv de 1637
# Faltan 103 archivos
#
# DataFrame con palabras clave para Under Startup Ideas_subconjunto.csv
#
# Archivo Under Startup Ideas_subconjunto.csv de 1637
# Faltan 102 archivos
#
# DataFrame con palabras clave para Underbanked Startup Ideas_subconjunto.csv
#
# Archivo Underbanked Startup Ideas_subconjunto.csv de 1637
# Faltan 101 archivos
#
# DataFrame con palabras clave para Understand Startup Ideas_subconjunto.csv
#
# Archivo Understand Startup Ideas_subconjunto.csv de 1637
# Faltan 100 archivos
#
# DataFrame con palabras clave para Understanding Startup Ideas_subconjunto.csv
#
# Archivo Understanding Startup Ideas_subconjunto.csv de 1637
# Faltan 99 archivos
#
# DataFrame con palabras clave para Unified Startup Ideas_subconjunto.csv
#
# Archivo Unified Startup Ideas_subconjunto.csv de 1637
# Faltan 98 archivos
#
# DataFrame con palabras clave para Unique Startup Ideas_subconjunto.csv
#
# Archivo Unique Startup Ideas_subconjunto.csv de 1637
# Faltan 97 archivos
#
# DataFrame con palabras clave para United Startup Ideas_subconjunto.csv
#
# Archivo United Startup Ideas_subconjunto.csv de 1637
# Faltan 96 archivos
#
# DataFrame con palabras clave para Universal Startup Ideas_subconjunto.csv
#
# Archivo Universal Startup Ideas_subconjunto.csv de 1637
# Faltan 95 archivos
#
# DataFrame con palabras clave para University Startup Ideas_subconjunto.csv
#
# Archivo University Startup Ideas_subconjunto.csv de 1637
# Faltan 94 archivos
#
# DataFrame con palabras clave para Unlock Startup Ideas_subconjunto.csv
#
# Archivo Unlock Startup Ideas_subconjunto.csv de 1637
# Faltan 93 archivos
#
# DataFrame con palabras clave para Unused Startup Ideas_subconjunto.csv
#
# Archivo Unused Startup Ideas_subconjunto.csv de 1637
# Faltan 92 archivos
#
# DataFrame con palabras clave para Update Startup Ideas_subconjunto.csv
#
# Archivo Update Startup Ideas_subconjunto.csv de 1637
# Faltan 91 archivos
#
# DataFrame con palabras clave para Upload Startup Ideas_subconjunto.csv
#
# Archivo Upload Startup Ideas_subconjunto.csv de 1637
# Faltan 90 archivos
#
# DataFrame con palabras clave para Urban Startup Ideas_subconjunto.csv
#
# Archivo Urban Startup Ideas_subconjunto.csv de 1637
# Faltan 89 archivos
#
# DataFrame con palabras clave para Usage Startup Ideas_subconjunto.csv
#
# Archivo Usage Startup Ideas_subconjunto.csv de 1637
# Faltan 88 archivos
#
# DataFrame con palabras clave para Used Startup Ideas_subconjunto.csv
#
# Archivo Used Startup Ideas_subconjunto.csv de 1637
# Faltan 87 archivos
#
# DataFrame con palabras clave para Useful Startup Ideas_subconjunto.csv
#
# Archivo Useful Startup Ideas_subconjunto.csv de 1637
# Faltan 86 archivos
#
# DataFrame con palabras clave para User Startup Ideas_subconjunto.csv
#
# Archivo User Startup Ideas_subconjunto.csv de 1637
# Faltan 85 archivos
#
# DataFrame con palabras clave para Utility Startup Ideas_subconjunto.csv
#
# Archivo Utility Startup Ideas_subconjunto.csv de 1637
# Faltan 84 archivos
#
# DataFrame con palabras clave para Vacation Startup Ideas_subconjunto.csv
#
# Archivo Vacation Startup Ideas_subconjunto.csv de 1637
# Faltan 83 archivos
#
# DataFrame con palabras clave para Valley Startup Ideas_subconjunto.csv
#
# Archivo Valley Startup Ideas_subconjunto.csv de 1637
# Faltan 82 archivos
#
# DataFrame con palabras clave para Valuable Startup Ideas_subconjunto.csv
#
# Archivo Valuable Startup Ideas_subconjunto.csv de 1637
# Faltan 81 archivos
#
# DataFrame con palabras clave para Valuation Startup Ideas_subconjunto.csv
#
# Archivo Valuation Startup Ideas_subconjunto.csv de 1637
# Faltan 80 archivos
#
# DataFrame con palabras clave para Value Startup Ideas_subconjunto.csv
#
# Archivo Value Startup Ideas_subconjunto.csv de 1637
# Faltan 79 archivos
#
# DataFrame con palabras clave para Variety Startup Ideas_subconjunto.csv
#
# Archivo Variety Startup Ideas_subconjunto.csv de 1637
# Faltan 78 archivos
#
# DataFrame con palabras clave para Vc Startup Ideas_subconjunto.csv
#
# Archivo Vc Startup Ideas_subconjunto.csv de 1637
# Faltan 77 archivos
#
# DataFrame con palabras clave para Vehicle Startup Ideas_subconjunto.csv
#
# Archivo Vehicle Startup Ideas_subconjunto.csv de 1637
# Faltan 76 archivos
#
# DataFrame con palabras clave para Venmo Startup Ideas_subconjunto.csv
#
# Archivo Venmo Startup Ideas_subconjunto.csv de 1637
# Faltan 75 archivos
#
# DataFrame con palabras clave para Venture Startup Ideas_subconjunto.csv
#
# Archivo Venture Startup Ideas_subconjunto.csv de 1637
# Faltan 74 archivos
#
# DataFrame con palabras clave para Verify Startup Ideas_subconjunto.csv
#
# Archivo Verify Startup Ideas_subconjunto.csv de 1637
# Faltan 73 archivos
#
# DataFrame con palabras clave para Version Startup Ideas_subconjunto.csv
#
# Archivo Version Startup Ideas_subconjunto.csv de 1637
# Faltan 72 archivos
#
# DataFrame con palabras clave para Very Startup Ideas_subconjunto.csv
#
# Archivo Very Startup Ideas_subconjunto.csv de 1637
# Faltan 71 archivos
#
# DataFrame con palabras clave para Vet Startup Ideas_subconjunto.csv
#
# Archivo Vet Startup Ideas_subconjunto.csv de 1637
# Faltan 70 archivos
#
# DataFrame con palabras clave para Vetted Startup Ideas_subconjunto.csv
#
# Archivo Vetted Startup Ideas_subconjunto.csv de 1637
# Faltan 69 archivos
#
# DataFrame con palabras clave para Video Startup Ideas_subconjunto.csv
#
# Archivo Video Startup Ideas_subconjunto.csv de 1637
# Faltan 68 archivos
#
# DataFrame con palabras clave para View Startup Ideas_subconjunto.csv
#
# Archivo View Startup Ideas_subconjunto.csv de 1637
# Faltan 67 archivos
#
# DataFrame con palabras clave para Virtual Startup Ideas_subconjunto.csv
#
# Archivo Virtual Startup Ideas_subconjunto.csv de 1637
# Faltan 66 archivos
#
# DataFrame con palabras clave para Visa Startup Ideas_subconjunto.csv
#
# Archivo Visa Startup Ideas_subconjunto.csv de 1637
# Faltan 65 archivos
#
# DataFrame con palabras clave para Visibility Startup Ideas_subconjunto.csv
#
# Archivo Visibility Startup Ideas_subconjunto.csv de 1637
# Faltan 64 archivos
#
# DataFrame con palabras clave para Vision Startup Ideas_subconjunto.csv
#
# Archivo Vision Startup Ideas_subconjunto.csv de 1637
# Faltan 63 archivos
#
# DataFrame con palabras clave para Visit Startup Ideas_subconjunto.csv
#
# Archivo Visit Startup Ideas_subconjunto.csv de 1637
# Faltan 62 archivos
#
# DataFrame con palabras clave para Visual Startup Ideas_subconjunto.csv
#
# Archivo Visual Startup Ideas_subconjunto.csv de 1637
# Faltan 61 archivos
#
# DataFrame con palabras clave para Visualization Startup Ideas_subconjunto.csv
#
# Archivo Visualization Startup Ideas_subconjunto.csv de 1637
# Faltan 60 archivos
#
# DataFrame con palabras clave para Visualize Startup Ideas_subconjunto.csv
#
# Archivo Visualize Startup Ideas_subconjunto.csv de 1637
# Faltan 59 archivos
#
# DataFrame con palabras clave para Visually Startup Ideas_subconjunto.csv
#
# Archivo Visually Startup Ideas_subconjunto.csv de 1637
# Faltan 58 archivos
#
# DataFrame con palabras clave para Voice Startup Ideas_subconjunto.csv
#
# Archivo Voice Startup Ideas_subconjunto.csv de 1637
# Faltan 57 archivos
#
# DataFrame con palabras clave para Vote Startup Ideas_subconjunto.csv
#
# Archivo Vote Startup Ideas_subconjunto.csv de 1637
# Faltan 56 archivos
#
# DataFrame con palabras clave para Vr Startup Ideas_subconjunto.csv
#
# Archivo Vr Startup Ideas_subconjunto.csv de 1637
# Faltan 55 archivos
#
# DataFrame con palabras clave para Wait Startup Ideas_subconjunto.csv
#
# Archivo Wait Startup Ideas_subconjunto.csv de 1637
# Faltan 54 archivos
#
# DataFrame con palabras clave para Walking Startup Ideas_subconjunto.csv
#
# Archivo Walking Startup Ideas_subconjunto.csv de 1637
# Faltan 53 archivos
#
# DataFrame con palabras clave para Wallet Startup Ideas_subconjunto.csv
#
# Archivo Wallet Startup Ideas_subconjunto.csv de 1637
# Faltan 52 archivos
#
# DataFrame con palabras clave para Walmart Startup Ideas_subconjunto.csv
#
# Archivo Walmart Startup Ideas_subconjunto.csv de 1637
# Faltan 51 archivos
#
# DataFrame con palabras clave para Wanted Startup Ideas_subconjunto.csv
#
# Archivo Wanted Startup Ideas_subconjunto.csv de 1637
# Faltan 50 archivos
#
# DataFrame con palabras clave para Warehouse Startup Ideas_subconjunto.csv
#
# Archivo Warehouse Startup Ideas_subconjunto.csv de 1637
# Faltan 49 archivos
#
# DataFrame con palabras clave para Waste Startup Ideas_subconjunto.csv
#
# Archivo Waste Startup Ideas_subconjunto.csv de 1637
# Faltan 48 archivos
#
# DataFrame con palabras clave para Watch Startup Ideas_subconjunto.csv
#
# Archivo Watch Startup Ideas_subconjunto.csv de 1637
# Faltan 47 archivos
#
# DataFrame con palabras clave para Watching Startup Ideas_subconjunto.csv
#
# Archivo Watching Startup Ideas_subconjunto.csv de 1637
# Faltan 46 archivos
#
# DataFrame con palabras clave para Water Startup Ideas_subconjunto.csv
#
# Archivo Water Startup Ideas_subconjunto.csv de 1637
# Faltan 45 archivos
#
# DataFrame con palabras clave para Wearable Startup Ideas_subconjunto.csv
#
# Archivo Wearable Startup Ideas_subconjunto.csv de 1637
# Faltan 44 archivos
#
# DataFrame con palabras clave para Weather Startup Ideas_subconjunto.csv
#
# Archivo Weather Startup Ideas_subconjunto.csv de 1637
# Faltan 43 archivos
#
# DataFrame con palabras clave para Web Startup Ideas_subconjunto.csv
#
# Archivo Web Startup Ideas_subconjunto.csv de 1637
# Faltan 42 archivos
#
# DataFrame con palabras clave para Website Startup Ideas_subconjunto.csv
#
# Archivo Website Startup Ideas_subconjunto.csv de 1637
# Faltan 41 archivos
#
# DataFrame con palabras clave para Wedding Startup Ideas_subconjunto.csv
#
# Archivo Wedding Startup Ideas_subconjunto.csv de 1637
# Faltan 40 archivos
#
# DataFrame con palabras clave para Week Startup Ideas_subconjunto.csv
#
# Archivo Week Startup Ideas_subconjunto.csv de 1637
# Faltan 39 archivos
#
# DataFrame con palabras clave para Weekly Startup Ideas_subconjunto.csv
#
# Archivo Weekly Startup Ideas_subconjunto.csv de 1637
# Faltan 38 archivos
#
# DataFrame con palabras clave para Weight Startup Ideas_subconjunto.csv
#
# Archivo Weight Startup Ideas_subconjunto.csv de 1637
# Faltan 37 archivos
#
# DataFrame con palabras clave para Were Startup Ideas_subconjunto.csv
#
# Archivo Were Startup Ideas_subconjunto.csv de 1637
# Faltan 36 archivos
#
# DataFrame con palabras clave para Whatsapp Startup Ideas_subconjunto.csv
#
# Archivo Whatsapp Startup Ideas_subconjunto.csv de 1637
# Faltan 35 archivos
#
# DataFrame con palabras clave para Whether Startup Ideas_subconjunto.csv
#
# Archivo Whether Startup Ideas_subconjunto.csv de 1637
# Faltan 34 archivos
#
# DataFrame con palabras clave para While Startup Ideas_subconjunto.csv
#
# Archivo While Startup Ideas_subconjunto.csv de 1637
# Faltan 33 archivos
#
# DataFrame con palabras clave para White Startup Ideas_subconjunto.csv
#
# Archivo White Startup Ideas_subconjunto.csv de 1637
# Faltan 32 archivos
#
# DataFrame con palabras clave para Whole Startup Ideas_subconjunto.csv
#
# Archivo Whole Startup Ideas_subconjunto.csv de 1637
# Faltan 31 archivos
#
# DataFrame con palabras clave para Whose Startup Ideas_subconjunto.csv
#
# Archivo Whose Startup Ideas_subconjunto.csv de 1637
# Faltan 30 archivos
#
# DataFrame con palabras clave para Wi Startup Ideas_subconjunto.csv
#
# Archivo Wi Startup Ideas_subconjunto.csv de 1637
# Faltan 29 archivos
#
# DataFrame con palabras clave para Wide Startup Ideas_subconjunto.csv
#
# Archivo Wide Startup Ideas_subconjunto.csv de 1637
# Faltan 28 archivos
#
# DataFrame con palabras clave para Willing Startup Ideas_subconjunto.csv
#
# Archivo Willing Startup Ideas_subconjunto.csv de 1637
# Faltan 27 archivos
#
# DataFrame con palabras clave para Wine Startup Ideas_subconjunto.csv
#
# Archivo Wine Startup Ideas_subconjunto.csv de 1637
# Faltan 26 archivos
#
# DataFrame con palabras clave para Within Startup Ideas_subconjunto.csv
#
# Archivo Within Startup Ideas_subconjunto.csv de 1637
# Faltan 25 archivos
#
# DataFrame con palabras clave para Women Startup Ideas_subconjunto.csv
#
# Archivo Women Startup Ideas_subconjunto.csv de 1637
# Faltan 24 archivos
#
# DataFrame con palabras clave para Word Startup Ideas_subconjunto.csv
#
# Archivo Word Startup Ideas_subconjunto.csv de 1637
# Faltan 23 archivos
#
# DataFrame con palabras clave para Worked Startup Ideas_subconjunto.csv
#
# Archivo Worked Startup Ideas_subconjunto.csv de 1637
# Faltan 22 archivos
#
# DataFrame con palabras clave para Workflow Startup Ideas_subconjunto.csv
#
# Archivo Workflow Startup Ideas_subconjunto.csv de 1637
# Faltan 21 archivos
#
# DataFrame con palabras clave para Workforce Startup Ideas_subconjunto.csv
#
# Archivo Workforce Startup Ideas_subconjunto.csv de 1637
# Faltan 20 archivos
#
# DataFrame con palabras clave para Working Startup Ideas_subconjunto.csv
#
# Archivo Working Startup Ideas_subconjunto.csv de 1637
# Faltan 19 archivos
#
# DataFrame con palabras clave para Workout Startup Ideas_subconjunto.csv
#
# Archivo Workout Startup Ideas_subconjunto.csv de 1637
# Faltan 18 archivos
#
# DataFrame con palabras clave para Workplace Startup Ideas_subconjunto.csv
#
# Archivo Workplace Startup Ideas_subconjunto.csv de 1637
# Faltan 17 archivos
#
# DataFrame con palabras clave para Workspace Startup Ideas_subconjunto.csv
#
# Archivo Workspace Startup Ideas_subconjunto.csv de 1637
# Faltan 16 archivos
#
# DataFrame con palabras clave para World Startup Ideas_subconjunto.csv
#
# Archivo World Startup Ideas_subconjunto.csv de 1637
# Faltan 15 archivos
#
# DataFrame con palabras clave para Worldwide Startup Ideas_subconjunto.csv
#
# Archivo Worldwide Startup Ideas_subconjunto.csv de 1637
# Faltan 14 archivos
#
# DataFrame con palabras clave para Worth Startup Ideas_subconjunto.csv
#
# Archivo Worth Startup Ideas_subconjunto.csv de 1637
# Faltan 13 archivos
#
# DataFrame con palabras clave para Write Startup Ideas_subconjunto.csv
#
# Archivo Write Startup Ideas_subconjunto.csv de 1637
# Faltan 12 archivos
#
# DataFrame con palabras clave para Writing Startup Ideas_subconjunto.csv
#
# Archivo Writing Startup Ideas_subconjunto.csv de 1637
# Faltan 11 archivos
#
# DataFrame con palabras clave para Written Startup Ideas_subconjunto.csv
#
# Archivo Written Startup Ideas_subconjunto.csv de 1637
# Faltan 10 archivos
#
# DataFrame con palabras clave para Y Startup Ideas_subconjunto.csv
#
# Archivo Y Startup Ideas_subconjunto.csv de 1637
# Faltan 9 archivos
#
# DataFrame con palabras clave para Yc Startup Ideas_subconjunto.csv
#
# Archivo Yc Startup Ideas_subconjunto.csv de 1637
# Faltan 8 archivos
#
# DataFrame con palabras clave para Yelp Startup Ideas_subconjunto.csv
#
# Archivo Yelp Startup Ideas_subconjunto.csv de 1637
# Faltan 7 archivos
#
# DataFrame con palabras clave para Yet Startup Ideas_subconjunto.csv
#
# Archivo Yet Startup Ideas_subconjunto.csv de 1637
# Faltan 6 archivos
#
# DataFrame con palabras clave para Yoga Startup Ideas_subconjunto.csv
#
# Archivo Yoga Startup Ideas_subconjunto.csv de 1637
# Faltan 5 archivos
#
# DataFrame con palabras clave para York Startup Ideas_subconjunto.csv
#
# Archivo York Startup Ideas_subconjunto.csv de 1637
# Faltan 4 archivos
#
# DataFrame con palabras clave para Young Startup Ideas_subconjunto.csv
#
# Archivo Young Startup Ideas_subconjunto.csv de 1637
# Faltan 3 archivos
#
# DataFrame con palabras clave para Yourself Startup Ideas_subconjunto.csv
#
# Archivo Yourself Startup Ideas_subconjunto.csv de 1637
# Faltan 2 archivos
#
# DataFrame con palabras clave para Youtube Startup Ideas_subconjunto.csv
#
# Archivo Youtube Startup Ideas_subconjunto.csv de 1637
# Faltan 1 archivos
#
# DataFrame con palabras clave para Youve Startup Ideas_subconjunto.csv
#
# Archivo Youve Startup Ideas_subconjunto.csv de 1637
# Faltan 0 archivos

# %%
# Carpeta de exportación para CSV y JSON
carpeta_csv = 'csv-export'
carpeta_export = 'json-export'
os.makedirs(carpeta_export, exist_ok=True)

# Obtener la lista de archivos CSV en la carpeta csv-export
archivos_csv = glob.glob(os.path.join(carpeta_csv, '*.csv'))

# Iterar sobre los archivos CSV
for archivo_csv in archivos_csv:
    # Leer el archivo CSV en un DataFrame
    df = pd.read_csv(archivo_csv)

    # Agregar un campo ID al DataFrame
    df['ID'] = range(1, len(df) + 1)

    # Reorganizar las columnas para tener el campo "ID" primero
    df = df[['ID', 'Tag', 'Idea']]

    # Crear el nombre del archivo JSON
    nombre_json = os.path.splitext(os.path.basename(archivo_csv))[0] + '.json'
    ruta_json = os.path.join(carpeta_export, nombre_json)

    # Guardar el DataFrame como JSON en la carpeta de exportación
    df.to_json(ruta_json, orient='records', lines=True)
print(f'Se han creado {len(archivos_csv)} archivos JSON en la carpeta {carpeta_export}.')
